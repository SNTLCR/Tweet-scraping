# %%
# !pip install ntscraper

# %%
import pandas as pd
from ntscraper import Nitter

# %%
scraper = Nitter()
# Out:
# Testing instances: 100%|██████████| 31/31 [00:37<00:00,  1.22s/it]

# %%
tweets = scraper.get_tweets('domestic abuse',mode = 'hashtag',number = 50000)
# Out:
# INFO:root:No instance specified, using random instance https://nitter.projectsegfau.lt
# INFO:root:Current stats for domestic abuse: 9 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 23 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 35 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 42 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 57 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 67 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 79 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 86 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 92 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 101 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 109 tweets, 0 threads...
# INFO:root:Current stats for domestic abuse: 121 tweets, 0 threads...
# ...

# %%
tweets
# Out:
# {'tweets': [{'link': 'https://twitter.com/CollagesNyc/status/1742412169684340796#m',
#    'text': 'Femicides are an act of hate.  Rakesh Kamal shot and killed his wife and teenage daughter and then killed himself 4 days ago.  #DomesticViolence #femicide https://www.cbsnews.com/boston/news/dover-massachusetts-murder-suicide-teena-kamal-arianna-kamal-rakesh-kamal/',
#    'user': {'name': 'feminist_collages_ nyc',
#     'username': '@CollagesNyc',
#     'profile_id': '1436828865889021956',
#     'avatar': 'https://pbs.twimg.com/profile_images/1436828865889021956/SDa861yO_bigger.jpg'},
#    'date': 'Jan 3, 2024 · 5:06 AM UTC',
#    'is-retweet': True,
#    'external-link': '',
#    'replying_to': [],
#    'quoted-post': {},
#    'stats': {'comments': 4, 'retweets': 46, 'quotes': 0, 'likes': 121},
#    'pictures': ['https://pbs.twimg.com/media/GC5KojkbcAE4_FN.jpg'],
#    'videos': [],
#    'gifs': []},
#   {'link': 'https://twitter.com/GhioLena/status/1747033249287655725#m',
# ...

# %%
final_tweets = []
for tweet in tweets['tweets']:
  data = [tweet['text'],tweet['date']]
  final_tweets.append(data)

# %%
data = pd.DataFrame(final_tweets,columns = ['text','date'])

# %%
data
# Out:
#                                                    text  \
# 0     Deaths caused by domestic  abuse are so common...
# 1     #laurenboebert (notice how #X refuses to give ...
# 2     A year in review: GMP’s response to tackling d...
# 3     @NestacUK speaking about hidden complex #traum...
# 4     Thoughts ??? #men #women #abuse #domestic viol...
# ...                                                 ...
# 3426  Thank you to @coastlandsnews  for inviting Spe...
# 3427  #Domestic Violence and Abuse: Recognizing the ...
# 3428  #Domestic #abuse victims school #priority #edu...
# 3429                                    #DOMESTIC ABUSE
# 3430  We welcome inclusion of #economicabuse in the ...
#
#                              date
# 0      Jan 14, 2024 · 2:08 PM UTC
# 1      Jan 13, 2024 · 7:35 PM UTC
# 2     Jan 13, 2024 · 11:00 AM UTC
# 3       Jan 9, 2024 · 1:16 PM UTC
# 4       Jan 6, 2024 · 8:55 AM UTC
# ...                           ...
# 3426   Mar 6, 2019 · 10:44 AM UTC
# ...

# %%
data.to_csv('tweets.csv')
